# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sea

# %% [markdown]
# #### Importing the libraries pandas ,matplotlib.pyplot an seaborn from python, in order to perform column operations on the dataset

# %%
amazon=pd.read_csv("C:/Users/navee/Downloads/python dataset/amazon sales/amazon.csv")

# %%
amazon
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
amazon.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %% [markdown]
# #### Displaying the variable names in the dataset.

# %%
amazon['total']=amazon['discounted_price']+amazon['actual_price']

# %%
amazon
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# #### Added a new variable in the dataset by combining the variables actual price  and listing price.

# %%
amazon.rename(columns={'total':'grand total'})
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
amazon.rename(columns={'actual_price':'Original Price','total':'final'})
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# #### Renamed Two variables 'actual price' as 'Original Price' and 'total' as 'final'.

# %%
amazon.drop(['rating','rating_count'],axis=1)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# ##### We have dropped the variables 'Ratings' and 'rating count' from the dataset.

# %%
amazon.columns=[col.upper()for col in amazon.columns]

# %%
amazon
# Out:
#       PRODUCT_ID                                       PRODUCT_NAME  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                CATEGORY DISCOUNTED_PRICE  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# #### Displayed the Variables name of the dataset in the Uppercase.

# %%
amazon.columns=[col.lower()for col in amazon.columns]

# %%
amazon
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# #### Displayed the Variables name of the dataset in the lowercase.

# %%
amazon.sort_values(by=['actual_price','discounted_price'],ascending=[True,False])
# Out:
#       product_id                                       product_name  \
# 1264  B08235JZFB  Crompton InstaGlide 1000-Watts Dry Iron with A...
# 343   B0BDRVFDKP  SanDisk Ultra® microSDXC™ UHS-I Card, 64GB, 14...
# 593   B0BDRVFDKP  SanDisk Ultra® microSDXC™ UHS-I Card, 64GB, 14...
# 1048  B096YCN3SD  Lifelong LLEK15 Electric Kettle 1.5L with Stai...
# 775   B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# ...          ...                                                ...
# 938   B0994GFWBH  Lapster 1.5 mtr USB 2.0 Type A Male to USB A M...
# 653   B0B9LDCX89  STRIFF Mpad Mouse Mat 230X190X3mm Gaming Mouse...
# 552   B08BCKN299  Sounce Gold Plated 3.5 mm Headphone Splitter f...
# 962   B08BCKN299  Sounce Gold Plated 3.5 mm Headphone Splitter f...
# 870   B0994GP1CX  LS LAPSTER Quality Assured Universal Silicone ...
#
#                                                category discounted_price  \
# 1264  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...             ₹850
# ...

# %% [markdown]
# ##### In this we have sorted two variables 'actual_price' and 'discount price' and then we have arranged the variable 'actual_Price' in the ascending order.

# %%
amazon.sort_values(by='total',ascending=True)
# Out:
#       product_id                                       product_name  \
# 1033  B00NW4UWN6  Prestige PKGSS 1.7L 1500W Electric Kettle (Sta...
# 1089  B09ZTZ9N3Q  Amazon Basics 2000/1000 Watt Room Heater with ...
# 1214  B0B84KSH3X  Wipro Vesta 1200 Watt GD203 Heavyweight Automa...
# 671   B0B12K5BPM  ZEBRONICS Zeb-Astra 20 Wireless BT v5.0 Portab...
# 1258  B0836JGZ74  CSI INTERNATIONAL® Instant Water Geyser, Water...
# ...          ...                                                ...
# 644   B085HY1DGR  Sounce Spiral Charger Cable Protector Data Cab...
# 602   B08W56G1K9  LAPSTER Spiral Charger Spiral Charger Cable Pr...
# 557   B0BBW521YC  LAPSTER 12pcs Spiral Cable Protectors for Char...
# 407   B085HY1DGR  Sounce Spiral Charger Cable Protector Data Cab...
# 920   B08X77LM8C  Silicone Rubber Earbuds Tips, Eartips, Earpads...
#
#                                                category discounted_price  \
# 1033  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹1,043
# ...

# %% [markdown]
# #### Sorted the variable named 'total' and arranged its values in ascending order.

# %%
amazon.sort_values(by='total')
# Out:
#       product_id                                       product_name  \
# 1033  B00NW4UWN6  Prestige PKGSS 1.7L 1500W Electric Kettle (Sta...
# 1089  B09ZTZ9N3Q  Amazon Basics 2000/1000 Watt Room Heater with ...
# 1214  B0B84KSH3X  Wipro Vesta 1200 Watt GD203 Heavyweight Automa...
# 671   B0B12K5BPM  ZEBRONICS Zeb-Astra 20 Wireless BT v5.0 Portab...
# 1258  B0836JGZ74  CSI INTERNATIONAL® Instant Water Geyser, Water...
# ...          ...                                                ...
# 644   B085HY1DGR  Sounce Spiral Charger Cable Protector Data Cab...
# 602   B08W56G1K9  LAPSTER Spiral Charger Spiral Charger Cable Pr...
# 557   B0BBW521YC  LAPSTER 12pcs Spiral Cable Protectors for Char...
# 407   B085HY1DGR  Sounce Spiral Charger Cable Protector Data Cab...
# 920   B08X77LM8C  Silicone Rubber Earbuds Tips, Eartips, Earpads...
#
#                                                category discounted_price  \
# 1033  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹1,043
# ...

# %% [markdown]
# #### We have sorted the variable named 'total'.

# %%
amazon.drop(['actual_price'],axis=1,inplace=True)

# %% [markdown]
# #### We have dropped the variable named 'actual_price' and used inplace function.¶

# %%
amazon
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
amazon.groupby('discounted_price').count()
# Out:
#                   product_id  product_name  category  discount_percentage  \
# discounted_price
# ₹1,043                     1             1         1                    1
# ₹1,049                     5             5         5                    5
# ₹1,052                     1             1         1                    1
# ₹1,055                     1             1         1                    1
# ₹1,059                     1             1         1                    1
# ...                      ...           ...       ...                  ...
# ₹980                       1             1         1                    1
# ₹99                       15            15        15                   15
# ₹998                       1             1         1                    1
# ₹998.06                    1             1         1                    1
# ₹999                      25            25        25                   25
#
# ...

# %% [markdown]
# ##### By Performing groupby function on discounted_price variable and used count function it is displays us this variable takes place in 227 observations.

# %%
print(amazon['discounted_price'].isnull().sum())
# Out:
# 0

# %% [markdown]
# #### There is no null values present in the 'discounted_price' variable.

# %%
print(amazon.columns.values)
# Out:
# ['product_id' 'product_name' 'category' 'discounted_price'
#  'discount_percentage' 'rating' 'rating_count' 'about_product' 'user_id'
#  'user_name' 'review_id' 'review_title' 'review_content' 'img_link'
#  'product_link' 'total']

# %% [markdown]
# #### Displayed the variables but by using print function.¶
